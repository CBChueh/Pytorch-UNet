# %%
# %run predict.py -vn -i  /home/cbchueh/Documents/Pytorch-UNet/output_picture/x_-3mm_y_0mm_20251218_172359/OCT_images/x_-3mm_y_0mm_20251218_172359_frame_087.jpg  \
    -m /home/cbchueh/Documents/Pytorch-UNet/checkpoints/checkpoint_epoch50.pth

# %%
# !python predict_Folder.py  -i  "/home/cbchueh/Documents/Pytorch-UNet/output_picture/"  \
    -m /home/cbchueh/Documents/Pytorch-UNet/checkpoints/checkpoint_epoch50.pth
# Out:
# INFO: Loading model /home/cbchueh/Documents/Pytorch-UNet/checkpoints/checkpoint_epoch50.pth
# INFO: Using device cuda
# INFO: Model loaded!
# L
# INFO: 0 Mask saved to /home/cbchueh/Documents/Pytorch-UNet/output_picture/x_-9mm_y_0mm_20251218_175305/OCT_images_mask_predict/x_-9mm_y_0mm_20251218_175305_frame_268.jpg
# L
# INFO: 1 Mask saved to /home/cbchueh/Documents/Pytorch-UNet/output_picture/x_-9mm_y_0mm_20251218_175305/OCT_images_mask_predict/x_-9mm_y_0mm_20251218_175305_frame_270.jpg
# L
# INFO: 2 Mask saved to /home/cbchueh/Documents/Pytorch-UNet/output_picture/x_-9mm_y_0mm_20251218_175305/OCT_images_mask_predict/x_-9mm_y_0mm_20251218_175305_frame_194.jpg
# L
# INFO: 3 Mask saved to /home/cbchueh/Documents/Pytorch-UNet/output_picture/x_-9mm_y_0mm_20251218_175305/OCT_images_mask_predict/x_-9mm_y_0mm_20251218_175305_frame_246.jpg
# L
# ...
